# %% [markdown]
# ## Importando as bibliotecas

# %% [markdown]
# **Documentações:**
# - Numpy: https://numpy.org/doc/stable/
# - Pandas: https://pandas.pydata.org/docs/index.html

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %% [markdown]
# ## Importando e conhecendo a Base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dados = pd.read_csv('caminho_para_o_arquivo', sep = ';')

# %% [markdown]
# O dataset que iremos utilizar é formado por registros de imóveis para locação, localizados no Rio de Janeiro.

# %% [markdown]
# Verificando o tipo do dado

# %%
#type(dados)

# %% [markdown]
# Informações sobre o dataframe

# %%
#com o describe()

# %%
#com o info()

# %%
#com o shape

# %%
#print('A base de dados apresenta {} registros (imóveis) e {} variáveis'.format( , ))

# %% [markdown]
# ## A partir daqui, após conhecer a base de dados, você pode:
# - Agrupar variáveis (colunas)
# - Criar novos DataFrames
# - Fazer seleções
# - Tratar dados faltantes
# - Excluir ou adicionar variáveis
# - Fazer análises com gráficos
